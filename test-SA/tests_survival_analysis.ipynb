# %%
import pandas as pd
import csv
import os
import numpy as np
from pycaret.survival_analysis.oop import SurvivalAnalysisExperiment
from pycaret.regression.oop import RegressionExperiment
import lifelines

# %%
# List the files in the current directory
files = os.listdir('./csv')
# Get the absolute path of the current directory
current_dir = os.getcwd()
# Create a DataFrame with the file names and their absolute paths
file_paths = pd.DataFrame({
    'file_name': files,
    'absolute_path': [os.path.join(current_dir, 'csv', file) for file in files]
})

# %%
# Load the CSV file into a DataFrame 
df = pd.read_csv(file_paths['absolute_path'][0], index_col=0)

# %%
features_to_drop = df.columns[16:]
df = df.drop(features_to_drop, axis=1)
df
# Out:
#           ID  age  eventdeath   survival  timerecurrence  chemo  hormonal  \
# Patient
# s122      18   43           0  14.817248       14.817248      0         0
# s123      19   48           0  14.261465       14.261465      0         0
# s124      20   38           0   6.644764        6.644764      0         0
# s125      21   50           0   7.748118        7.748118      0         1
# s126      22   38           0   6.436687        6.318960      0         0
# ...      ...  ...         ...        ...             ...    ...       ...
# s71      308   48           1   2.608300        1.982204      1         0
# s72      309   39           1   5.504100        3.028063      0         0
# s73      310   50           1   2.619200        2.149213      0         0
# s75      311   52           1   2.290500        2.209446      0         1
# s76      312   52           1   3.737000        2.127310      0         0
#
#          amputation  histtype  diam  posnodes  grade  angioinv  lymphinfil  \
# Patient
# s122              1         1    25         0      2         3           1
# s123              0         1    20         0      3         3           1
# s124              0         1    15         0      2         1           1
# s125              0         1    15         1      2         3           1
# s126              1         1    15         0      2         2           1
# ...             ...       ...   ...       ...    ...       ...         ...
# s71               1         1    30         0      3         1           3
# s72               1         1    30         0      2         1           1
# s73               1         1    27         0      3         1           1
# s75               1         1    28         0      3         1           1
# s76               1         1    30         0      2         1           1
#
#          barcode      esr1
# Patient
# s122        6274 -0.413955
# s123        6275  0.195251
# s124        6276  0.596177
# s125        6277  0.501286
# s126        6278 -0.066771
# ...          ...       ...
# s71         4321 -1.235442
# s72         4322  0.062265
# s73         4323 -0.635322
# s75         4325 -1.055801
# s76         4326 -1.063121
#
# [272 rows x 16 columns]

# %%
features_to_drop
# Out:
# Index(['G3PDH_570', 'Contig45645_RC', 'Contig44916_RC', 'D25272', 'J00129',
#        'Contig29982_RC', 'Contig56678_RC', 'Contig53047_RC', 'Contig19551',
#        'Contig47230_RC',
#        ...
#        'Contig36312_RC', 'Contig38980_RC', 'NM_000853', 'NM_000854',
#        'NM_000860', 'Contig29014_RC', 'Contig46616_RC', 'NM_000888',
#        'NM_000898', 'AF067420'],
#       dtype='object', length=1553)

# %%
exp1 = SurvivalAnalysisExperiment()
exp1.setup(data=df,
            duration="timerecurrence",
            target="eventdeath",
            ignore_features=['ID', 'Patient'],
            log_data=True,
            fold=20
           )
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[6], line 2
#       1 exp1 = SurvivalAnalysisExperiment()
# ----> 2 exp1.setup(data=df,
#       3             duration="timerecurrence",
#       4             target="eventdeath",
#       5             ignore_features=['ID', 'Patient'],
#       6             log_data=True,
#       7             fold=20
#       8            )
#
# TypeError: SurvivalAnalysisExperiment.setup() got an unexpected keyword argument 'duration'

# %%
print(exp1.models())
# Out:
#                                    Name  \
# ID
# cox                      Cox Regression
# aa                       Aalen Additive
# cs                           CRC Spline
# ctv                    Cox Time Varying
# ggr        Generalized Gamma Regression
# llaft                  Log Logistic AFT
# lnaft                    Log Normal AFT
# pwer   Piecewise Exponential Regression
# waft                        Weibull AFT
#
#                                                Reference  Turbo
# ID
# cox    lifelines.utils.sklearn_adapter.SkLearnCoxPHFi...   True
# aa     lifelines.utils.sklearn_adapter.SkLearnAalenAd...   True
# cs     lifelines.utils.sklearn_adapter.SkLearnCRCSpli...   True
# ctv    lifelines.utils.sklearn_adapter.SkLearnCoxTime...   True
# ggr    lifelines.utils.sklearn_adapter.SkLearnGeneral...   True
# llaft  lifelines.utils.sklearn_adapter.SkLearnLogLogi...   True
# lnaft  lifelines.utils.sklearn_adapter.SkLearnLogNorm...   True
# pwer   lifelines.utils.sklearn_adapter.SkLearnPiecewi...   True
# waft   lifelines.utils.sklearn_adapter.SkLearnWeibull...   True

# %%
# cox = exp1.create_model('cox')
model = exp1.create_model('cox')
# Out:
#
#
# Initiated  . . . . . . . . . . . . . . . . . .              12:38:24
# Status     . . . . . . . . . . . . . . . . . .  Loading Dependencies
# Estimator  . . . . . . . . . . . . . . . . . .     Compiling Library
# Processing:   0%|          | 0/4 [00:00<?, ?it/s]

# %%
model = exp1.tune_model(model)
# Out:
#
#
# Initiated  . . . . . . . . . . . . . . . . . .              12:41:53
# Status     . . . . . . . . . . . . . . . . . .  Loading Dependencies
# Estimator  . . . . . . . . . . . . . . . . . .     Compiling Library
# Processing:   0%|          | 0/7 [00:00<?, ?it/s]
# Fitting 20 folds for each of 4 candidates, totalling 80 fits
# Original model was better than the tuned model, hence it will be returned. NOTE: The display metrics are for the tuned model (not the original one).

# %%
prediction = exp1.predict_model(model, data=df)
prediction
# Out:
#       age  eventdeath   survival  chemo  hormonal  amputation  histtype  diam  \
# 0    43.0         0.0  14.817248    0.0       0.0         1.0       1.0  25.0
# 1    48.0         0.0  14.261465    0.0       0.0         0.0       1.0  20.0
# 2    38.0         0.0   6.644764    0.0       0.0         0.0       1.0  15.0
# 3    50.0         0.0   7.748118    0.0       1.0         0.0       1.0  15.0
# 4    38.0         0.0   6.436687    0.0       0.0         1.0       1.0  15.0
# ..    ...         ...        ...    ...       ...         ...       ...   ...
# 267  48.0         1.0   2.608300    1.0       0.0         1.0       1.0  30.0
# 268  39.0         1.0   5.504100    0.0       0.0         1.0       1.0  30.0
# 269  50.0         1.0   2.619200    0.0       0.0         1.0       1.0  27.0
# 270  52.0         1.0   2.290500    0.0       1.0         1.0       1.0  28.0
# 271  52.0         1.0   3.737000    0.0       0.0         1.0       1.0  30.0
#
#      posnodes  grade  angioinv  lymphinfil  barcode  timerecurrence      Label
# 0         0.0    2.0       3.0         1.0   6274.0       14.817248  17.874729
# 1         0.0    3.0       3.0         1.0   6275.0       14.261465  17.619638
# 2         0.0    2.0       1.0         1.0   6276.0        6.644764   7.255338
# 3         1.0    2.0       3.0         1.0   6277.0        7.748118   9.771463
# 4         0.0    2.0       2.0         1.0   6278.0        6.318960   6.275861
# ..        ...    ...       ...         ...      ...             ...        ...
# 267       0.0    3.0       1.0         3.0   4321.0        1.982204   1.749354
# 268       0.0    2.0       1.0         1.0   4322.0        3.028063   5.011133
# 269       0.0    3.0       1.0         1.0   4323.0        2.149213   1.221810
# 270       0.0    3.0       1.0         1.0   4325.0        2.209446   1.594492
# 271       0.0    2.0       1.0         1.0   4326.0        2.127310   2.453305
#
# [272 rows x 15 columns]

# %%
exp1.plot_model(model, plot='test')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [26], in <cell line: 1>()
# ----> 1 exp1.plot_model(model, plot='test')
#
# File ~\OneDrive\Documents\ECOLE\Stage\GRIIS_Medomics\MEDml\pycaret_local\pycaret\survival_analysis\oop.py:1837, in plot_model(self, estimator, plot, scale, save, fold, fit_kwargs, plot_kwargs, groups, use_train_data, verbose, display_format)
#    1728 def plot_model(
#    1729     self,
#    1730     estimator,
#    (...)
#    1740     display_format: Optional[str] = None,
#    1741 ) -> Optional[str]:
#    1743     """
#    1744     This function analyzes the performance of a trained model on holdout set.
#    1745     It may require re-training the model in certain cases.
#    (...)
#    1832
#    1833     """
#    1835     return super().plot_model(
#    1836         estimator=estimator,
# -> 1837         plot=plot,
#    1838         scale=scale,
#    1839         save=save,
#    1840         fold=fold,
#    1841         fit_kwargs=fit_kwargs,
#    1842         plot_kwargs=plot_kwargs,
#    1843         groups=groups,
#    1844         verbose=verbose,
#    1845         use_train_data=use_train_data,
#    1846         display_format=display_format,
#    1847     )
#
# File ~\OneDrive\Documents\ECOLE\Stage\GRIIS_Medomics\MEDml\pycaret_local\pycaret\internal\pycaret_experiment\tabular_experiment.py:2093, in _TabularExperiment.plot_model(self, estimator, plot, scale, save, fold, fit_kwargs, plot_kwargs, groups, feature_name, label, use_train_data, verbose, display_format)
#    1979 def plot_model(
#    1980     self,
#    1981     estimator,
#    (...)
#    1993     display_format: Optional[str] = None,
#    1994 ) -> Optional[str]:
#    1996     """
#    1997     This function takes a trained model object and returns a plot based on the
#    1998     test / hold-out set. The process may require the model to be re-trained in
#    (...)
#    2091
#    2092     """
# -> 2093     return self._plot_model(
#    2094         estimator=estimator,
#    2095         plot=plot,
#    2096         scale=scale,
#    2097         save=save,
#    2098         fold=fold,
#    2099         fit_kwargs=fit_kwargs,
#    2100         plot_kwargs=plot_kwargs,
#    2101         groups=groups,
#    2102         feature_name=feature_name,
#    2103         label=label,
#    2104         use_train_data=use_train_data,
#    2105         verbose=verbose,
#    2106         display_format=display_format,
#    2107     )
#
# File ~\OneDrive\Documents\ECOLE\Stage\GRIIS_Medomics\MEDml\pycaret_local\pycaret\internal\pycaret_experiment\tabular_experiment.py:406, in _TabularExperiment._plot_model(self, estimator, plot, scale, save, fold, fit_kwargs, plot_kwargs, groups, feature_name, label, use_train_data, verbose, system, display, display_format)
#     401     raise ValueError(
#     402         f"Estimator {estimator} does not have the required fit() method."
#     403     )
#     405 if plot not in self._available_plots:
# --> 406     raise ValueError(
#     407         "Plot Not Available. Please see docstring for list of available Plots."
#     408     )
#     410 # checking display_format parameter
#     411 self.plot_model_check_display_format_(display_format=display_format)
#
# ValueError: Plot Not Available. Please see docstring for list of available Plots.
